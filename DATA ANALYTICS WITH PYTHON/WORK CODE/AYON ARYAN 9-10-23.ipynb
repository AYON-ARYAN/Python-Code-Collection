# %%
import pandas as pd
od=pd.read_csv("2median_odd_exercise.csv")

# %%
od
# Out:
#    scores
# 0      85
# 1      90
# 2      75
# 3      80
# 4      95
# 5      92
# 6      88
# 7      87
# 8      91

# %%
od.median()
# Out:
# scores    88.0
# dtype: float64

# %%
od.mean()
# Out:
# scores    87.0
# dtype: float64

# %%
ev=pd.read_csv("2median_even_exercise.csv")

# %%
ev
# Out:
#    Race_minutes
# 0            85
# 1            90
# 2            75
# 3            80
# 4            95
# 5            92
# 6            88
# 7            87
# 8            91
# 9            79

# %%
ev.median()
# Out:
# Race_minutes    87.5
# dtype: float64

# %%
ev.mean()
# Out:
# Race_minutes    86.2
# dtype: float64

# %%
exe=pd.read_csv("1experience.csv")
exe
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2
# 5              2.9
# 6              3.0
# 7              3.2
# 8              3.2

# %%
exe.median()
# Out:
# YearsExperience    2.2
# dtype: float64

# %%
exe.mean()
# Out:
# YearsExperience    2.266667
# dtype: float64

# %%
sa=pd.read_csv("3Salary_Data.csv")
sa
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
sa.mean()
# Out:
# YearsExperience        5.313333
# Salary             76003.000000
# dtype: float64

# %%
sa.median()
# Out:
# YearsExperience        4.7
# Salary             65237.0
# dtype: float64

# %%
#4laptops.csv
la=pd.read_csv("4laptops.csv")
la
# Out:
#     Manufacturer       Model_Name   Category  Screen_size_inches  \
# 0          Apple      MacBook Pro  Ultrabook                13.3
# 1          Apple      Macbook Air  Ultrabook                13.3
# 2             HP           250 G6   Notebook                15.6
# 3          Apple      MacBook Pro  Ultrabook                15.4
# 4          Apple      MacBook Pro  Ultrabook                13.3
# ..           ...              ...        ...                 ...
# 972         Dell     Alienware 17     Gaming                17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook                14.0
# 974         Asus        Rog Strix     Gaming                17.3
# 975           HP      Probook 450   Notebook                15.6
# 976       Lenovo    ThinkPad T460   Notebook                14.0
#
#                                  Screen                          CPU   RAM  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# ...

# %%
la.head(5)
# Out:
#   Manufacturer   Model_Name   Category  Screen_size_inches  \
# 0        Apple  MacBook Pro  Ultrabook                13.3
# 1        Apple  Macbook Air  Ultrabook                13.3
# 2           HP       250 G6   Notebook                15.6
# 3        Apple  MacBook Pro  Ultrabook                15.4
# 4        Apple  MacBook Pro  Ultrabook                13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating_System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# ...

# %%
la['Screen_size_inches'].median(),la['Price'].median()
# Out:
# (15.6, 8527428.0)

# %%
print("MEDIAN OF SCREEN SIZE OF ALL LAPTOPS =\n",la['Screen_size_inches'].median())
print("MEDIAN OF PRICE OF ALL LAPTOPS =\n",la['Price'].median())
# Out:
# MEDIAN OF SCREEN SIZE OF ALL LAPTOPS =
#  15.6
# MEDIAN OF PRICE OF ALL LAPTOPS =
#  8527428.0

# %%
mcd=pd.read_csv("6Mcd.csv")

# %%
mcd
# Out:
#     Unnamed: 0  Year  McDonalds_Revenue_$Billion  Growth_rate_percent    Q1  \
# 0            0  1999                        13.3              2.73913  5.43
# 1            1  2000                        14.2              7.00000  5.43
# 2            2  2001                        14.9              4.00000  5.43
# 3            3  2002                        15.4              4.00000  5.43
# 4            4  2003                        17.1             11.00000  3.80
# 5            5  2004                        18.6              8.00000  4.40
# 6            6  2005                        19.1              3.00000  4.80
# 7            7  2006                        20.9              9.00000  4.90
# 8            8  2007                        22.8              9.00000  5.30
# 9            9  2008                        23.5              3.00000  5.60
# 10          10  2009                        22.7             -3.00000  5.10
# ...

# %%
print("MEDIAN OF GROWTH RATE PERCENT =\n",mcd['Growth_rate_percent'].median())
# Out:
# MEDIAN OF GROWTH RATE PERCENT =
#  2.8695652173913047
