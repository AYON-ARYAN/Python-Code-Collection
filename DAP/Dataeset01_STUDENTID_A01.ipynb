# %% [markdown]
# ## Student Name:## FULL NAME [edit]
#
# **Student ID:**  RVUN23BCSXXX [edit]
#
# **Section H**
#
# **Assessment:** Measurement of Central Tendencies

# %% [markdown]
# Assessment Instructions:
#
# - Do not delete cells containing #ans.
# - Do not remove #ans from the cell before writing the code.
# - Do not create extra cells to write the code.
# - Write all lines of code in the assigned question placeholder.
# - Use the same Dataset {CSV} file name directly as instructed in the assessment.
#
#       1.  Put the Dataset.csv file in the same location/directory as notebook.ipynb file.
#       2.  Example: pd.read_csv("dataset_name.csv")
#
# - Use the print() function to display the output or solution of the problem given, Also check the demonstration below.
#
#       1.   Incorrect way: print("The Calculated Mean of the given task is: ", Answer)
#       2.   Correct way: print(answer)
#
#
# - Save the submission file with your ID_FULL NAME [IN BLOCK LETTERS].
#
# **Total Time:** 35 Minutes [ Including 15 min to upload and Download the File ]

# %% [markdown]
# **Import** the required library and **read** the assigned Dataset.

# %%
#write the code below this line.
import pandas as pd
a= pd.read_csv("/Volumes/PEN DRIVE/DATA ANALYTICS WITH PYTHON/student_data_part_1.csv")
a
# Out:
#    Student_Name  Marks  Grade_Point Letter_Grade  Course_Hours
# 0   Student_301     51     1.885331            A            20
# 1   Student_302     93     3.242443            D            45
# 2   Student_303     43     1.526920            D            18
# 3   Student_304     13     1.396479            B            18
# 4   Student_305     31     2.618223            F            36
# 5   Student_306     24     3.914469            C            17
# 6   Student_307     24     2.592557            A            32
# 7   Student_308     68     3.740461            A            43
# 8   Student_309     57     3.491418            C             6
# 9   Student_310     17     1.770910            E             8
# 10  Student_311     54     3.474069            E            48
# 11  Student_312     23     2.445543            A            26
# 12  Student_313     35     3.419465            C             3
# 13  Student_314     59     3.239678            C            17
# ...

# %% [markdown]
# Question 1:
#
# Calculate the average marks of the students?

# %%
#ans1
# write line of code below this line
b = '/Volumes/PEN DRIVE/DATA ANALYTICS WITH PYTHON/student_data_part_1.csv'
data = pd.read_csv(b)
avg = data['Marks'].mean()
avg
# Out:
# 48.72

# %% [markdown]
# Question 2:
#
# Calculate the median for course hours attribute in the given dataset?

# %%
#ans2
# write line of code below this line
data = pd.read_csv(b)
med= data['Course_Hours'].median()
med
# Out:
# 25.5

# %% [markdown]
# Question 3:
#
# What is the most common grade achieved by the students?

# %%
#ans3
# write line of code below this line






pp= '/Volumes/PEN DRIVE/DATA ANALYTICS WITH PYTHON/student_data_part_1.csv'


data = pd.read_csv(pp)


jj = 'Letter_Grade'


mod = data[jj].mode()[0]

print(f"The most common grade achieved by students is: {mod}")
# Out:
# The most common grade achieved by students is: C

# %% [markdown]
# Question 4:
#
# Compare the measure of central tendency and Analyse which is the best measure for the Grade points?
#
# **Note** Final Answer must be the value from the best measure of Central Tendency.

# %%
#ans4
# write line of code below this line
#The mean (average), median, and mode are the most widely used metrics to describe central tendency. Every metric has advantages of its own and is applicable in certain situations.

#1. To compute the mean, sum up all the values, then divide the total by the number of values.
#2. The middle number obtained by sorting the data in ascending order is called the median. The median is the average of the two middle values when the number of values is even.
#3. The value that appears the most frequently in the dataset is the mode.


#mean
data = pd.read_csv(b)
med= data['Course_Hours'].mean()
med
# Out:
# 26.18

# %% [markdown]
# Justify your answer for the question no. 04.

# %% [markdown]
# The mean (average), median, and mode are the most widely used metrics to describe central tendency. Every metric has advantages of its own and is applicable in certain situations.
#
# 1. To compute the mean, sum up all the values, then divide the total by the number of values.
# 2. The middle number obtained by sorting the data in ascending order is called the median. The median is the average of the two middle values when the number of values is even.
# 3. The value that appears the most frequently in the dataset is the mode.
#
#
#
#
#
# ** Write the justification statement below this line **
