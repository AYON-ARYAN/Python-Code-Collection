# %%
import pandas as pd
da=pd.read_csv("/Volumes/PEN DRIVE/DATA ANALYTICS WITH PYTHON/drive-download-20230921T170244Z-001/1range_exercise.csv")
da
# Out:
#    marks
# 0     17
# 1     22
# 2      9
# 3     13
# 4     25
# 5     20
# 6     15

# %%
da.min(),da.max()
# Out:
# (marks    9
#  dtype: int64,
#  marks    25
#  dtype: int64)

# %%
da.

# %%
da.mean()
# Out:
# marks    17.285714
# dtype: float64

# %%
da.mode()
# Out:
#    marks
# 0      9
# 1     13
# 2     15
# 3     17
# 4     20
# 5     22
# 6     25

# %%
da.max()-da.min()
# Out:
# marks    16
# dtype: int64

# %%
dp=pd.read_csv("/Volumes/PEN DRIVE/DATA ANALYTICS WITH PYTHON/drive-download-20230921T170244Z-001/3Salary_Data.csv")
dp
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
dp.max()-dp.min()
# Out:
# YearsExperience        9.4
# Salary             84660.0
# dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dp.max[YearsExperience]
#
# NameError: name 'YearsExperience' is not defined

# %%
dpp=pd.read_csv("/Volumes/PEN DRIVE/DATA ANALYTICS WITH PYTHON/drive-download-20230921T170244Z-001/4laptops.csv")
dpp
# Out:
#     Manufacturer       Model_Name   Category  Screen_size_inches  \
# 0          Apple      MacBook Pro  Ultrabook                13.3
# 1          Apple      Macbook Air  Ultrabook                13.3
# 2             HP           250 G6   Notebook                15.6
# 3          Apple      MacBook Pro  Ultrabook                15.4
# 4          Apple      MacBook Pro  Ultrabook                13.3
# ..           ...              ...        ...                 ...
# 972         Dell     Alienware 17     Gaming                17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook                14.0
# 974         Asus        Rog Strix     Gaming                17.3
# 975           HP      Probook 450   Notebook                15.6
# 976       Lenovo    ThinkPad T460   Notebook                14.0
#
#                                  Screen                          CPU   RAM  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# ...

# %%
dpp['Screen_size_inches'].max()
# Out:
# 18.4

# %%
dpp['Screen_size_inches'].min()
# Out:
# 10.1

# %%
dpp['Screen_size_inches'].max()-dpp['Screen_size_inches'].min()
# Out:
# 8.299999999999999

# %%
a=dpp['Screen_size_inches'].max()-dpp['Screen_size_inches'].min()

# %%
a
# Out:
# 8.299999999999999

# %%
dap=pd.read_csv("/Volumes/PEN DRIVE/DATA ANALYTICS WITH PYTHON/7games.csv")
dap
# Out:
#       Unnamed: 0                                    Title Release_Date  \
# 0              0                               Elden Ring    25-Feb-22
# 1              1                                    Hades    10-Dec-19
# 2              2  The Legend of Zelda: Breath of the Wild     3-Mar-17
# 3              3                                Undertale    15-Sep-15
# 4              4                          Hollow 000night    24-Feb-17
# ...          ...                                      ...          ...
# 1507        1507           Bac000 to the Future: The Game    22-Dec-10
# 1508        1508                        Team Sonic Racing    21-May-19
# 1509        1509                           Dragon's Dogma    22-May-12
# 1510        1510                          Baldur's Gate 3     6-Oct-20
# 1511        1511                 The LEGO Movie Videogame     4-Feb-14
#
#                                                    Team  Rating  Times_Listed  \
# ...

# %%
dap['Playing'].max()-dap['Playing'].min()
# Out:
# 38000

# %%
dap['Plays'].max()-dap['Plays'].min()
# Out:
# 99000
